# %%
import pandas as pd
import json
import sys
sys.path.append('..')
from scripts import util

# %%
conn = util.connect_rds()

# %%
sql = 'select * from rws_schema.hectopunten limit 100;'

# %%
df = pd.read_sql(sql, con=conn)

# %%
df.shape
# Out:
# (100, 296)

# %%
df.describe()
# Out:
#          jaar        wvk_id  hectomtrng      afstand    jte_id_beg  \
# count   100.0  1.000000e+02   100.00000   100.000000  1.000000e+02
# mean   2018.0  3.584120e+08   686.50000   442.440000  3.584121e+08
# std       0.0  7.761763e+07   468.70366   484.728547  7.761764e+07
# min    2018.0  2.613650e+08   100.00000     0.000000  2.613650e+08
# 25%    2018.0  2.613650e+08   104.00000   104.750000  2.613651e+08
# 50%    2018.0  4.173430e+08  1045.00000   296.000000  4.173430e+08
# 75%    2018.0  4.193440e+08  1054.00000   604.750000  4.193441e+08
# max    2018.0  4.623550e+08  1282.00000  3573.000000  4.623550e+08
#
#          jte_id_end       gme_id   endafstand   distrcode  weerstation  \
# count  1.000000e+02   100.000000   100.000000  100.000000    100.00000
# mean   3.606819e+08   864.800000  1398.750000  170.110000    263.43000
# std    7.733843e+07   880.081814  1459.886168   12.770622     18.52994
# min    2.603650e+08   150.000000   108.000000  159.000000    240.00000
# ...
