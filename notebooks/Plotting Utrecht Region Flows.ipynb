# %% [markdown]
# ## Aim: Plotting the lat-long data of induction loops downloaded from the NDW website filtered by searching for "Utrecht" in zoekterm.

# %%
import pandas as pd

# %%
import sys

# %%
sys.path.append('..')

# %%
from scripts import util

# %%
conn = util.connect_rds()

# %%
q = 'select * from rws_raw.utrecht_day'

# %%
df = pd.read_sql(q, con=conn)

# %%
ut = df[['startLocatieForDisplayLat',
       'startLocatieForDisplayLong']].drop_duplicates()

# %%
ut.shape
# Out:
# (1764, 2)

# %%
ut['startLocatieForDisplayLat'] = pd.to_numeric(ut.startLocatieForDisplayLat)

# %%
ut['startLocatieForDisplayLong'] = pd.to_numeric(ut.startLocatieForDisplayLong)

# %%
util.plot_coords(lat=ut.startLocatieForDisplayLat, long=ut.startLocatieForDisplayLong, map_type='markers')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
